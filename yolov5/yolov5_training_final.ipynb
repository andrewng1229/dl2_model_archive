# %%
# !pip install yolov5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.4/953.4 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.0/722.0 kB 23.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 16.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 15.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 59.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 18.3 MB/s eta 0:00:00
# ...

# %%
import yolov5

# %%
# !unzip  /content/project_json_augmented.zip -d /content/project_json_augmented
# Out:
# Archive:  /content/project_json_augmented.zip
#    creating: /content/project_json_augmented/project_json_augmented/
#    creating: /content/project_json_augmented/project_json_augmented/dataset/
#    creating: /content/project_json_augmented/project_json_augmented/dataset/images_/
#    creating: /content/project_json_augmented/project_json_augmented/dataset/images_/test/
#   inflating: /content/project_json_augmented/project_json_augmented/dataset/images_/test/bird_andrew_00064.jpg
#   inflating: /content/project_json_augmented/project_json_augmented/dataset/images_/test/bird_derrick_00097.jpg
#   inflating: /content/project_json_augmented/project_json_augmented/dataset/images_/test/bird_eddie_00000.jpg
#   inflating: /content/project_json_augmented/project_json_augmented/dataset/images_/test/bird_eddie_00234.jpg
#   inflating: /content/project_json_augmented/project_json_augmented/dataset/images_/test/bird_henry_00064.jpg
# ...

# %%
from yolov5 import train, val, detect, export

train.run(imgsz=640, data='/content/project_json_augmented/project_json_augmented/project_json_augmented.yaml',epochs=30,batch_size =24 ,weights='yolov5s.pt')
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/project_json_augmented/project_json_augmented/project_json_augmented.yaml, hyp=../usr/local/lib/python3.10/dist-packages/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=24, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, bbox_interval=-1, artifact_alias=latest, neptune_token=None, neptune_project=None, neptune_resume_id=None, s3_upload_dir=None, upload_dataset=False, hf_model_id=None, hf_token=None, hf_private=False, hf_dataset_id=None, roboflow_token=None, roboflow_upload=False
# YOLOv5 🚀 2024-3-21 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
export.run(weights='/content/runs/train/exp2/weights/best.pt')
# Out:
# YOLOv5 🚀 2024-3-20 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7042489 parameters, 0 gradients, 15.9 GFLOPs
# WARNING ⚠️ --img-size [680, 680] must be multiple of max stride 32, updating to [704, 704]
# image 1/1 /content/project_json/project_json/dataset/images/test/horse_henry_00088.jpg: 416x704 1 horse, 10.3ms
# Speed: 0.5ms pre-process, 10.3ms inference, 1.7ms NMS per image at shape (1, 3, 704, 704)
# Results saved to runs/detect/exp3
